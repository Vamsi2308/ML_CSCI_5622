# %% [markdown]
# ## Traffic_Stations Data

# %%
import requests
import csv
import os

# %%
## Let's build the csv file
## first and add the column names
## Create a new csv file to save the headlines
filename="data.csv"
MyFILE=open(filename,"w")  # "a"  for append   "r" for read
## with open
### Place the column names in - write to the first row
WriteThis="OBJECTID,STATION_NUMBER,STATION_TEXT,TRAFFIC_COUNT,TRAFFIC_YEAR_COUNTED,BIKE_COUNT,BIKE_YEAR_COUNTED,STATUS,STREET_NAME,CHRIS_NUMB,PAVETYPE,FUNCTIONAL_CLASS,TrafficStationID \n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
URL="https://maps.bouldercounty.org/arcgis/rest/services/Transportation/Traffic_Stations/MapServer/0/query?outFields=*&where=1%3D1&f=geojson"

response=requests.get(URL)
print(response)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    jsontxt = response.json()
    print(jsontxt)
else:
    print('Error:', response.status_code)
# Out:
# <Response [200]>
# {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 922931, 'geometry': {'type': 'Point', 'coordinates': [-105.16581436731632, 39.986817707434085]}, 'properties': {'OBJECTID': 922931, 'STATION_NUMBER': 277, 'STATION_TEXT': '277', 'TRAFFIC_COUNT': 14863, 'TRAFFIC_YEAR_COUNTED': 2022, 'BIKE_COUNT': 159, 'BIKE_YEAR_COUNTED': 2018, 'STATUS': 'Active Station', 'STREET_NAME': 'SOUTH BOULDER RD', 'CHRIS_NUMB': '006003', 'PAVETYPE': 'Concrete', 'FUNCTIONAL_CLASS': 'Principal Arterial', 'TrafficStationID': 2925074}}, {'type': 'Feature', 'id': 922932, 'geometry': {'type': 'Point', 'coordinates': [-105.17695191272732, 39.98676857045314]}, 'properties': {'OBJECTID': 922932, 'STATION_NUMBER': 279, 'STATION_TEXT': '279', 'TRAFFIC_COUNT': 10548, 'TRAFFIC_YEAR_COUNTED': 2022, 'BIKE_COUNT': 150, 'BIKE_YEAR_COUNTED': 2018, 'STATUS': 'Active Station', 'STREET_NAME': 'SOUTH BOULDER RD', 'CHRIS_NUMB': '006002', 'PAVETYPE': 'Concrete', 'FUNCTIONAL_CLASS': 'Principal Arterial', 'TrafficStationID': 2925076}}, {'type': 'Feature', 'id': 922933, 'geometry': {'type': 'Point', 'coordinates': [-105.210782681214, 39.986125998091886]}, 'properties': {'OBJECTID': 922933, 'STATION_NUMBER': 281, 'STATION_TEXT': '281', 'TRAFFIC_COUNT': 9973, 'TRAFFIC_YEAR_COUNTED': 2022, 'BIKE_COUNT': 171, 'BIKE_YEAR_COUNTED': 2016, 'STATUS': 'Active Station', 'STREET_NAME': 'SOUTH BOULDER RD', 'CHRIS_NUMB': '006002', 'PAVETYPE': 'Concrete', 'FUNCTIONAL_CLASS': 'Principal Arterial', 'TrafficStationID': 2925081}}, {'type': 'Feature', 'id': 922935, 'geometry': {'type': 'Point', 'coordinates': [-105.2776784897178, 40.10526128549303]}, 'properties': {'OBJECTID': 922935, 'STATION_NUMBER': 145, 'STATION_TEXT': '145', 'TRAFFIC_COUNT': 1295, 'TRAFFIC_YEAR_COUNTED': 2022, 'BIKE_COUNT': 101, 'BIKE_YEAR_COUNTED': 2022, 'STATUS': 'Active Station', 'STREET_NAME': 'NEVA RD', 'CHRIS_NUMB': '003401', 'PAVETYPE': 'Asphalt', 'FUNCTIONAL_CLASS': 'Collector', 'TrafficStationID': 2925199}}, {'type': 'Feature', 'id': 922940, 'geometry': {'type': 'Point', 'coordinates': [-105.25981841887601, 40.10403999060606]}, 'properties': {'OBJECTID': 922940, 'STATION_NUMBER': 127, 'STATION_TEXT': '127', 'TRAFFIC_COUNT': 622, 'TRAFFIC_YEAR_COUNTED': 2022, 'BIKE_COUNT': 13, 'BIKE_YEAR_COUNTED': 2020, 'STATUS': 'Active Station', 'STREET_NAME': 'FAIRWAYS DR', 'CHRIS_NUMB': '426606', 'PAVETYPE': 'Asphalt', 'FUNCTIONAL_CLASS': 'Residential Collector', 'TrafficStationID': 2925333}}, {'type': 'Feature', 'id': 922950, 'geometry': {'type': 'Point', 'coordinates': [-105.36304664220872, 40.057213674151576]}, 'properties': {'OBJECTID': 922950, 'STATION_NUMBER': 469, 'STATION_TEXT': '469', 'TRAFFIC_COUNT': 206, 'TRAFFIC_YEAR_COUNTED': 2022, 'BIKE_COUNT': None, 'BIKE_YEAR_COUNTED': None, 'STATUS': 'Active Station', 'STREET_NAME': 'CR 83', 'CHRIS_NUMB': '008300', 'PAVETYPE': 'Gravel', 'FUNCTIONAL_CLASS': 'Local', 'TrafficStationID': 2925376}}, {'type': 'Feature', 'id': 922969, 'geometry': {'type': 'Point', 'coordinates': [-105.07879110064808, 40.06947182895726]}, 'properties': {'OBJECTID': 922969, 'STATION_NUMBER': 607, 'STATION_TEXT': '607', 'TRAFFIC_COUNT': 1070, 'TRAFFIC_YEAR_COUNTED': 2020, 'BIKE_COUNT': 3, 'BIKE_YEAR_COUNTED': 2020, 'STATUS': 'Active Station', 'STREET_NAME': 'KENOSHA RD', 'CHRIS_NUMB': '003806', 'PAVETYPE': 'Asphalt', 'FUNCTIONAL_CLASS': 'Collector', 'TrafficStationID': 2925393}}, {'type': 'Feature', 'id': 922970, 'geometry': {'type': 'Point', 'coordinates': [-105.09802914798527, 40.04037632467848]}, 'properties': {'OBJECTID': 922970, 'STATION_NUMBER': 199, 'STATION_TEXT': '199', 'TRAFFIC_COUNT': 930, 'TRAFFIC_YEAR_COUNTED': 2020, 'BIKE_COUNT': 40, 'BIKE_YEAR_COUNTED': 2020, 'STATUS': 'Active Station', 'STREET_NAME': 'N 109TH ST', 'CHRIS_NUMB': '', 'PAVETYPE': 'Asphalt', 'FUNCTIONAL_CLASS': 'Local', 'TrafficStationID': 2925309}}, {'type': 'Feature', 'id': 922971, 'geometry': {'type': 'Point', 'coordinates': [-105.07092607455114,  ...

# %%
# Define the CSV file path
csv_file_path = 'data.csv'

# Extract specific fields from the JSON data
data_to_extract = []
for feature in jsontxt['features']:
    extracted_data = [
        feature['properties']['OBJECTID'],
        feature['properties']['STATION_NUMBER'],
        feature['properties']['STATION_TEXT'],
        feature['properties']['TRAFFIC_COUNT'],
        feature['properties']['TRAFFIC_YEAR_COUNTED'],
        feature['properties']['BIKE_COUNT'],
        feature['properties']['BIKE_YEAR_COUNTED'],
        feature['properties']['STATUS'],
        feature['properties']['STREET_NAME'],
        feature['properties']['CHRIS_NUMB'],
        feature['properties']['PAVETYPE'],
        feature['properties']['FUNCTIONAL_CLASS'],
        feature['properties']['TrafficStationID']
    ]
    data_to_extract.append(extracted_data)

# Open the CSV file in append mode and write data row by row
with open(csv_file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write a header row if the file is empty
    if os.path.getsize(csv_file_path) == 0:
        header_row = [
            'OBJECTID', 'STATION_NUMBER', 'STATION_TEXT',
            'TRAFFIC_COUNT', 'TRAFFIC_YEAR_COUNTED',
            'BIKE_COUNT', 'BIKE_YEAR_COUNTED',
            'STATUS', 'STREET_NAME', 'CHRIS_NUMB',
            'PAVETYPE', 'FUNCTIONAL_CLASS', 'TrafficStationID'
        ]
        csv_writer.writerow(header_row)
    
    # Write the extracted data row by row
    for row in data_to_extract:
        csv_writer.writerow(row)
